# %%
import numpy as np

# %% [raw]
# from PIL import as np

# %%
ones_arr=np.ones((3,3))
ones_arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones_arr*255
# Out:
# array([[255., 255., 255.],
#        [255., 255., 255.],
#        [255., 255., 255.]])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
horse_img=Image.open(r'C:\Users\premn\Downloads\horse.jpg')

# %%
horse_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x800>

# %%
type(horse_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
horse_arr=np.asarray(horse_img)
horse_arr
# Out:
# array([[[121, 125, 128],
#         [121, 125, 128],
#         [121, 125, 128],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [126, 127, 132]],
#
#        [[122, 126, 129],
#         [123, 124, 128],
#         [122, 123, 127],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [127, 128, 132]],
#
#        [[121, 122, 126],
#         [122, 123, 127],
#         [123, 124, 128],
#         ...,
#         [126, 127, 131],
#         [126, 127, 131],
#         [126, 127, 131]],
#
#        ...,
#
#        [[190, 151,  50],
#         [160, 126,  29],
#         [148, 123,  31],
#         ...,
#         [180, 141,  40],
#         [176, 137,  36],
#         [179, 141,  40]],
#
#        [[212, 166,  68],
#         [183, 147,  51],
#         [145, 120,  28],
#         ...,
#         [186, 147,  46],
#         [185, 146,  45],
#         [176, 138,  37]],
#
#        [[203, 153,  56],
#         [181, 142,  47],
#         [137, 112,  20],
#         ...,
#         [197, 159,  58],
#         [190, 152,  51],
#         [178, 141,  37]]], dtype=uint8)

# %%
type(horse_arr)
# Out:
# numpy.ndarray

# %%
horse_arr.shape
# Out:
# (800, 1280, 3)

# %%
plt.imshow(horse_arr)

# %%
image_red=horse_arr.copy()

# %%
image_red
# Out:
# array([[[121, 125, 128],
#         [121, 125, 128],
#         [121, 125, 128],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [126, 127, 132]],
#
#        [[122, 126, 129],
#         [123, 124, 128],
#         [122, 123, 127],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [127, 128, 132]],
#
#        [[121, 122, 126],
#         [122, 123, 127],
#         [123, 124, 128],
#         ...,
#         [126, 127, 131],
#         [126, 127, 131],
#         [126, 127, 131]],
#
#        ...,
#
#        [[190, 151,  50],
#         [160, 126,  29],
#         [148, 123,  31],
#         ...,
#         [180, 141,  40],
#         [176, 137,  36],
#         [179, 141,  40]],
#
#        [[212, 166,  68],
#         [183, 147,  51],
#         [145, 120,  28],
#         ...,
#         [186, 147,  46],
#         [185, 146,  45],
#         [176, 138,  37]],
#
#        [[203, 153,  56],
#         [181, 142,  47],
#         [137, 112,  20],
#         ...,
#         [197, 159,  58],
#         [190, 152,  51],
#         [178, 141,  37]]], dtype=uint8)

# %%
horse_red=horse_arr.copy()

# %%
horse_red
# Out:
# array([[[121, 125, 128],
#         [121, 125, 128],
#         [121, 125, 128],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [126, 127, 132]],
#
#        [[122, 126, 129],
#         [123, 124, 128],
#         [122, 123, 127],
#         ...,
#         [126, 127, 129],
#         [126, 127, 131],
#         [127, 128, 132]],
#
#        [[121, 122, 126],
#         [122, 123, 127],
#         [123, 124, 128],
#         ...,
#         [126, 127, 131],
#         [126, 127, 131],
#         [126, 127, 131]],
#
#        ...,
#
#        [[190, 151,  50],
#         [160, 126,  29],
#         [148, 123,  31],
#         ...,
#         [180, 141,  40],
#         [176, 137,  36],
#         [179, 141,  40]],
#
#        [[212, 166,  68],
#         [183, 147,  51],
#         [145, 120,  28],
#         ...,
#         [186, 147,  46],
#         [185, 146,  45],
#         [176, 138,  37]],
#
#        [[203, 153,  56],
#         [181, 142,  47],
#         [137, 112,  20],
#         ...,
#         [197, 159,  58],
#         [190, 152,  51],
#         [178, 141,  37]]], dtype=uint8)

# %%
horse_arr==horse_red
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
plt.imshow(horse_red)

# %%
horse_red.shape
# Out:
# (800, 1280, 3)

# %%
plt.imshow(horse_red[:,:,1])

# %%
plt.imshow(horse_red[:,:,0])

# %%
horse_red[:,:,0]
# Out:
# array([[121, 121, 121, ..., 126, 126, 126],
#        [122, 123, 122, ..., 126, 126, 127],
#        [121, 122, 123, ..., 126, 126, 126],
#        ...,
#        [190, 160, 148, ..., 180, 176, 179],
#        [212, 183, 145, ..., 186, 185, 176],
#        [203, 181, 137, ..., 197, 190, 178]], dtype=uint8)

# %%
plt.imshow(horse_red[:,:,0], cmap='pink')

# %%
plt.imshow(horse_red[:,:,2], cmap='Greys')

# %%
plt.imshow(horse_red[:,:,2], cmap='gray')

# %%
arr1 = np.asarray(horse_img)

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
# Out:
# (800, 1280, 3)

# %%
horse_red[:,:,2]=0

# %%
plt.imshow(horse_red)
